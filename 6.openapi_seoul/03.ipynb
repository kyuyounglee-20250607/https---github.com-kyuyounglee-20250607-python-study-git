# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/kyuyounglee-20250607/python-study-git/main/seoul_store.csv'
df = pd.read_csv(url,encoding='cp949')
df.head()

# %%
# %pip install matplotlib seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns  # matplotlib 를 감싼 wrapper 클래스
top10 = df.groupby('서비스_업종_코드_명')['당월_매출_금액'].sum().nlargest(10)
top10 = top10.to_frame()
top10 = top10.reset_index()
top10
# Out:
#   서비스_업종_코드_명      당월_매출_금액
# 0       한식음식점  4.760544e+13
# 1        일반의류  2.712249e+13
# 2        일반의원  2.306484e+13
# 3         의약품  2.127049e+13
# 4         편의점  1.773642e+13
# 5        슈퍼마켓  1.705082e+13
# 6  컴퓨터및주변장치판매  1.629611e+13
# 7       수산물판매  1.596464e+13
# 8        육류판매  1.264747e+13
# 9         청과상  1.179958e+13

# %%
import matplotlib.pyplot as plt
import matplotlib
import seaborn as sns

# 한글 폰트 설정
matplotlib.rcParams['font.family'] = 'Malgun Gothic'  # Windows용 한글 폰트
matplotlib.rcParams['axes.unicode_minus'] = False     # 음수 부호 깨짐 방지

# %%
plt.figure(figsize=(10,6))  # 그래프의 전체 크기를 설정
sns.barplot(data=top10,y = '서비스_업종_코드_명',x='당월_매출_금액', palette='viridis')
plt.title('업종별 당월 매출 상위 10개')
plt.xticks(rotation=45)
plt.xlabel('당월 매출 금액')
plt.ylabel('서비스 업종명')
plt.show()
# Out:
# C:\Users\tj\AppData\Local\Temp\ipykernel_7156\1908350940.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=top10,y = '서비스_업종_코드_명',x='당월_매출_금액', palette='viridis')

# %%
plt.figure(figsize=(10,6))  # 그래프의 전체 크기를 설정
sns.barplot(data=top10,x = '서비스_업종_코드_명',y='당월_매출_금액', palette='viridis')
plt.title('업종별 당월 매출 상위 10개')
plt.xticks(rotation=45)
plt.xlabel('당월 매출 금액')
plt.ylabel('서비스 업종명')
plt.show()
